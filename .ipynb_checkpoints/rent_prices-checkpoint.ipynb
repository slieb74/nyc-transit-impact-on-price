# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rent_prices = pd.read_csv('../datasets/Neighborhood_MedianRentalPrice_AllHomes.csv')
price_to_rent_ratio = pd.read_csv('../datasets/Neighborhood_PriceToRentRatio_AllHomes.csv')

# %%
p2r = price_to_rent_ratio[(price_to_rent_ratio.City=='New York') & ((price_to_rent_ratio.CountyName == 'New York') | (price_to_rent_ratio.CountyName =='Kings'))]

# %%
rent_prices[(rent_prices.CountyName=='Kings') | (rent_prices.CountyName=='New York')]
# Out:
#               RegionName      City State     Metro CountyName  SizeRank  \
# 3        Upper West Side  New York    NY  New York   New York         4
# 5        Upper East Side  New York    NY  New York   New York         6
# 11    Washington Heights  New York    NY  New York   New York        12
# 17          Williamsburg  New York    NY  New York      Kings        18
# 18    Bedford Stuyvesant  New York    NY  New York      Kings        19
# 22              Flatbush  New York    NY  New York      Kings        23
# 23         Crown Heights  New York    NY  New York      Kings        24
# 25                Harlem  New York    NY  New York   New York        26
# 27           East Harlem  New York    NY  New York   New York        28
# 28              Bushwick  New York    NY  New York      Kings        29
# 39           Bensonhurst  New York    NY  New York      Kings        40
# 46       Lower East Side  New York    NY  New York   New York        47
# ...

# %%
p2r
# Out:
#     RegionID                           RegionName      City State     Metro  \
# 0     270958                      Upper West Side  New York    NY  New York
# 1     270957                      Upper East Side  New York    NY  New York
# 2     194430                        East New York  New York    NY  New York
# 3     198687                   Washington Heights  New York    NY  New York
# 4     199001                         Williamsburg  New York    NY  New York
# 5     272902                   Bedford Stuyvesant  New York    NY  New York
# 6     194737                             Flatbush  New York    NY  New York
# 7     403222                        Crown Heights  New York    NY  New York
# 8     270828                          East Harlem  New York    NY  New York
# 9     193587                             Bushwick  New York    NY  New York
# 10    194379                        East Flatbush  New York    NY  New York
# ...

# %%
p2r = p2r.reset_index().drop(columns=['index'])

# %%
test = '2010-02-01'

# %%
date = pd.to_datetime(test,unit='D')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_with_unit_to_datetime()
#
# ValueError: could not convert string to float: '2010-02-01'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-3ba89ee2e090> in <module>()
# ----> 1 date = pd.to_datetime(test,unit='D')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     467             result = _convert_listlike(arg, box, format)
#     468     else:
# --> 469         result = _convert_listlike(np.array([arg]), box, format)[0]
#     470
#     471     return result
#
# ...

# %%
type(date)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# Out:
# (2010, 2)

# %%
rent_prices
# Out:
#                               RegionName             City State  \
# 0                       Northeast Dallas           Dallas    TX
# 1                               Paradise        Las Vegas    NV
# 2                               Maryvale          Phoenix    AZ
# 3                        Upper West Side         New York    NY
# 4                           Sherman Oaks      Los Angeles    CA
# 5                        Upper East Side         New York    NY
# 6                          Sunrise Manor        Las Vegas    NV
# 7                          Spring Valley        Las Vegas    NV
# 8                  Southeast Los Angeles      Los Angeles    CA
# 9                        Paradise Valley          Phoenix    AZ
# 10                           Deer Valley          Phoenix    AZ
# 11                    Washington Heights         New York    NY
# 12                              Van Nuys      Los Angeles    CA
# 13                               Astoria         New York    NY
# ...
